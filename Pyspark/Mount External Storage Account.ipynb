# %%
dbutils.fs.mounts()

# %%
dbutils.fs.unmount('/mnt/rainbowcontainer')

# %%
dbutils.fs.unmount('/mnt/rainbow-container')

# %%
secret_id = dbutils.secrets.get(scope="sc-quant-cloud-batch4", key="client-secret")
client_id = dbutils.secrets.get(scope="sc-quant-cloud-batch4", key="clinet-id")
tenent_id = dbutils.secrets.get(scope="sc-quant-cloud-batch4", key="tenent-id")

configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": client_id,
    "fs.azure.account.oauth2.client.secret": secret_id,
    "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenent_id}/oauth2/token"
}

# %%
container_name = "bronze-container"
storage_account = "rainbowstorageadls"
mount_path = "/mnt/QuantCloudContainer"

# %%
# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/",
  mount_point = mount_path,
  extra_configs = configs
)

# %%
dbutils.fs.mounts()

# %%
dbutils.fs.ls(mount_path)

# %%
# %fs
ls /mnt/QuantCloudContainer

# %%
# %fs
ls dbfs:/mnt/QuantCloudContainer/csv/

# %%
df = (
    spark.read.format("csv")
    .option("header", True)
    .option("inferSchema", True)
    .load("dbfs:/mnt/QuantCloudContainer/csv/videogames.csv")
)

display(df)

# %%
df.write.format("parquet").save("dbfs:/mnt/QuantCloudContainer/csv/parquet/video_games_dataset")
